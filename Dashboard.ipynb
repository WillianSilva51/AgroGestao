# %%
# %load_ext autoreload
# %autoreload 2
import panel as pn
# Importamos objetos de acesso a dados (DAO) para a lógica de negócios
from src.dao import produtor_dao 

pn.extension('tabulator', notifications=True)
